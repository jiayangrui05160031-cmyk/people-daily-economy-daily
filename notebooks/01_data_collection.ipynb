# %% [markdown]
# ## 📓 01 — 数据采集
#
# 目标:
# - 从 `finance.people.com.cn` 抓取指定日期经济新闻
# - 列表页分页 + 详情页正文提取
# - 输出 Article dataclass 列表,持久化为 JSON
#
# 对应模块: `src/scraper/`

# %%
import sys
sys.path.insert(0, '..')
from src.scraper.pipeline import fetch_previous_day_articles

# 抓取昨天的新闻
articles = fetch_previous_day_articles()
print(f'抓取 {len(articles)} 篇')
for a in articles[:3]:
    print(f'  - {a.title} ({a.publish_time}) [{a.channel}]')

# %% [markdown]
# ## ✅ 本节小结
#
# 完成数据采集。下一步: 👉 `02_nlp_analysis.ipynb` 做中文 NLP 分析。
