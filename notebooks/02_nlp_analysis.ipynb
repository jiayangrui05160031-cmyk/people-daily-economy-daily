# %% [markdown]
# ## 📓 02 — NLP 分析
#
# 目标:
# - jieba 分词 + 停用词过滤
# - TF-IDF + TextRank 双路融合关键词
# - 词频统计 + 产业关键词匹配
# - 词云图生成
#
# 对应模块: `src/nlp/`

# %%
import sys
sys.path.insert(0, '..')
from src.nlp.stats import analyze

stats = analyze(articles)
print('Top 10 关键词:')
for w, s in stats.keywords[:10]:
    print(f'  {w}: {s:.3f}')
print('\n命中产业:')
for name, count in stats.industry_hits.items():
    print(f'  {name}: {count} 次')

# %% [markdown]
# ## ✅ 本节小结
#
# 完成 NLP 特征提取。下一步: 👉 `03_ai_analysis.ipynb` 让 LLM 做 6 维度解读。
